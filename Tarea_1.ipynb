# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo 28

# %% [markdown]
# ## Integrantes:
# * Baltazar Portilla - Rol-1
# * Ivan Papic - 202273028-5

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (8.23.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: sqlparse in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (0.5.0)
# Requirement already satisfied: six in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: decorator in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: psycopg2 in c:\users\ipapi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.9.9)

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:Cowb0304__@localhost:5432/tarea_1
# Out:
# env: DATABASE_URL=postgresql://postgres:Cowb0304__@localhost:5432/tarea_1

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.

conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='tarea_1',
   password="Cowb0304__"
)

print(conn)
# Out:
# <connection object at 0x000002A65BCF6130; dsn: 'user=postgres password=xxx dbname=tarea_1 host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
# CREATE TABLE director (
#     id_director INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# )
# Out:
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# CREATE TABLE actor (
#     id_actor INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# CREATE TABLE pelicula (
#     id_pelicula INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_director INT NOT NULL,
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INT NOT NULL,
#     fecha_publicacion DATE NOT NULL,
#     FOREIGN KEY (id_director) REFERENCES director(id_director)
#         ON DELETE RESTRICT
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula (
#   id_actor INT,
#   id_pelicula INT NOT NULL,  -- Add NOT NULL constraint
#   FOREIGN KEY (id_actor) REFERENCES actor(id_actor),
#   FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# CREATE TABLE premio_mejor_director (
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_director INT NOT NULL,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_director) REFERENCES director(id_director)
#         ON DELETE CASCADE
#         ON UPDATE RESTRICT
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# CREATE TABLE premio_mejor_actor (
#     id_premio INT GENERATED ALWAYS AS IDENTITY,
#     id_actor INT NOT NULL,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_actor) REFERENCES actor(id_actor)
#         ON DELETE CASCADE
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# CREATE TABLE premio_mejor_pelicula (
#     id_premio INT GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INT NOT NULL,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula)
#         ON DELETE CASCADE
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 1988, 'director': 20, 'genero': 'Ciencia ficción', 'cast': [135], 'mejor pelicula': 'no'}, 2: {'año': 2007, 'director': 38, 'genero': 'Musical', 'cast': [66, 76], 'mejor pelicula': 'no'}, 3: {'año': 2002, 'director': 32, 'genero': 'Comedia', 'cast': [], 'mejor pelicula': 'no'}, 4: {'año': 2016, 'director': 135, 'genero': 'Drama', 'cast': [149, 108], 'mejor pelicula': 'no'}, 5: {'año': 2013, 'director': 4, 'genero': 'Comedia', 'cast': [196], 'mejor pelicula': 'no'}, 6: {'año': 1998, 'director': 188, 'genero': 'Western', 'cast': [], 'mejor pelicula': 'no'}, 7: {'año': 1980, 'director': 110, 'genero': 'Suspense', 'cast': [115, 34], 'mejor pelicula': 'no'}, 8: {'año': 2009, 'director': 100, 'genero': 'Comedia', 'cast': [], 'mejor pelicula': 'no'}, 9: {'año': 1977, 'director': 28, 'genero': 'Romance', 'cast': [108], 'mejor pelicula': 'no'}, 10: {'año': 2004, 'director': 1, 'genero': 'Misterio', 'cast': [51], 'mejor pelicula': 'no'}, 11: {'año': 2002, 'director': 15, 'genero': 'Misterio', 'cast': [194], 'mejor pelicula': 'no'}, 12: {'año': 1971, 'director': 113, 'genero': 'Documental', 'cast': [43, 79, 128, 180], 'mejor pelicula': 'no'}, 13: {'año': 2019, 'director': 188, 'genero': 'Romance', 'cast': [107], 'mejor pelicula': 'no'}, 14: {'año': 2011, 'director': 13, 'genero': 'Animación', 'cast': [12], 'mejor pelicula': 'no'}, 15: {'año': 1979, 'director': 128, 'genero': 'Ciencia ficción', 'cast': [14], 'mejor pelicula': 'no'}, 16: {'año': 1962, 'director': 184, 'genero': 'Terror', 'cast': [80, 62, 73], 'mejor pelicula': 'no'}, 17: {'año': 1988, 'director': 53, 'genero': 'Musical', 'cast': [148], 'mejor pelicula': 'no'}, 18: {'año': 1972, 'director': 56, 'genero': 'Suspense', 'cast': [14, 153, 41, 34], 'mejor pelicula': 'no'}, 19: {'año': 1993, 'director': 5, 'genero': 'Misterio', 'cast': [76, 17, 20], 'mejor pelicula': 'no'}, 20: {'año': 1984, 'director': 62, 'genero': 'Western', 'cast': [173, 191], 'mejor pelicula': 'no'}, 21: {'año': 2014, 'director': 130, 'genero': 'Western', 'cast': [116, 50], 'mejor pelicula': 'no'}, 22: {'año': 2001, 'director': 95, 'genero': 'Comedia', 'cast': [194], 'mejor pelicula': 'no'}, 23: {'año': 1991, 'director': 84, 'genero': 'Acción', 'cast': [19, 37], 'mejor pelicula': 'no'}, 24: {'año': 1970, 'director': 67, 'genero': 'Drama', 'cast': [55, 32], 'mejor pelicula': 'no'}, 25: {'año': 1971, 'director': 134, 'genero': 'Comedia', 'cast': [53, 166], 'mejor pelicula': 'no'}, 26: {'año': 1999, 'director': 15, 'genero': 'Comedia', 'cast': [], 'mejor pelicula': 'no'}, 27: {'año': 2009, 'director': 195, 'genero': 'Misterio', 'cast': [], 'mejor pelicula': 'no'}, 28: {'año': 2006, 'director': 150, 'genero': 'Musical', 'cast': [70], 'mejor pelicula': 'no'}, 29: {'año': 2003, 'director': 140, 'genero': 'Comedia', 'cast': [33, 157], 'mejor pelicula': 'no'}, 30: {'año': 2000, 'director': 44, 'genero': 'Musical', 'cast': [156, 117, 45], 'mejor pelicula': 'no'}, 31: {'año': 1993, 'director': 104, 'genero': 'Romance', 'cast': [77], 'mejor pelicula': 'no'}, 32: {'año': 1992, 'director': 43, 'genero': 'Comedia', 'cast': [11], 'mejor pelicula': 'no'}, 33: {'año': 1994, 'director': 68, 'genero': 'Fantasía', 'cast': [156, 60, 18], 'mejor pelicula': 'no'}, 34: {'año': 1998, 'director': 154, 'genero': 'Documental', 'cast': [68], 'mejor pelicula': 'no'}, 35: {'año': 2011, 'director': 189, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 36: {'año': 2013, 'director': 124, 'genero': 'Fantasía', 'cast': [], 'mejor pelicula': 'no'}, 37: {'año': 1997, 'director': 28, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 38: {'año': 2003, 'director': 38, 'genero': 'Drama', 'cast': [87, 114, 147, 86], 'mejor pelicula': 'no'}, 39: {'año': 1973, 'director': 98, 'genero': 'Drama', 'cast': [14, 139, 61, 46], 'mejor pelicula': 'no'}, 40: {'año': 1976, 'director': 24, 'genero': 'Animación', 'cast': [173, 29], 'mejor pelicula': 'no'}, 41: {'año': 1999, 'director': 62, 'genero': 'Acción', 'cast': [], 'mejor peli ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre, fecha_publicacion
# FROM pelicula
# WHERE genero = 'Drama'
# AND EXTRACT(YEAR FROM fecha_publicacion) = 2023;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT p.genero, COUNT(*) AS cantidad_premios
# FROM pelicula p
# INNER JOIN premio_mejor_pelicula pm ON p.id_pelicula = pm.id_pelicula
# GROUP BY p.genero
# ORDER BY cantidad_premios DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# 13 rows affected.
# [('Animación', 5),
#  ('Terror', 4),
#  ('Comedia', 4),
#  ('Documental', 3),
#  ('Drama', 3),
#  ('Musical', 3),
#  ('Misterio', 3),
#  ('Ciencia ficción', 3),
#  ('Suspense', 2),
#  ('Fantasía', 2),
#  ('Western', 2),
#  ('Aventura', 1),
#  ('Acción', 1)]

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT p.nombre AS pelicula,
#        MIN(a.edad) AS edad_actor_joven,
#        MAX(a.edad) AS edad_actor_viejo,
#        MAX(a.edad) - MIN(a.edad) AS brecha_edad
# FROM pelicula p
# INNER JOIN actor_participa_en_pelicula ap ON p.id_pelicula = ap.id_pelicula
# INNER JOIN actor a ON ap.id_actor = a.id_actor
# GROUP BY p.nombre
# ORDER BY brecha_edad DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# 1 rows affected.
# [('El viaje de el misterio', 15, 69, 54)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# WITH actores_con_mas_de_un_director AS (
#     SELECT ap.id_actor, COUNT(DISTINCT p.id_director) AS cantidad_directores
#     FROM actor_participa_en_pelicula ap
#     INNER JOIN pelicula p ON ap.id_pelicula = p.id_pelicula
#     GROUP BY ap.id_actor
#     HAVING COUNT(DISTINCT p.id_director) > 1
# )
#
# SELECT a.nombre AS nombre_actor, acd.cantidad_directores AS cantidad_directores,
#        p.nombre AS nombre_pelicula
# FROM actores_con_mas_de_un_director acd
# INNER JOIN actor a ON acd.id_actor = a.id_actor
# INNER JOIN actor_participa_en_pelicula ap ON a.id_actor = ap.id_actor
# INNER JOIN pelicula p ON ap.id_pelicula = p.id_pelicula
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# 447 rows affected.
# [('Ximena Ramos', 2, 'La cripta de el misterio'),
#  ('Jasmin Dutta', 6, 'El viaje de el misterio'),
#  ('Chen Rodriguez', 3, 'La travesía sin retorno de la magia'),
#  ('Mehmet Yan', 2, 'El castillo de la tormenta'),
#  ('Jasmin Dutta', 6, 'La leyenda perdida de el descubrimiento'),
#  ('Katarina Xia', 5, 'El renacimiento de el ángel'),
#  ('Oscar Zambrano', 4, 'La misión de la fuga'),
#  ('Wang Ferreira', 3, 'El renacimiento de la espada'),
#  ('Jasmin Dutta', 6, 'El castillo de el caos'),
#  ('Yasmin Hidalgo', 5, 'El descubrimiento de la compañía'),
#  ('Abdullah Nogueira', 5, 'La sombra de el susurro'),
#  ('Katarina Xia', 5, 'Las aventuras de la corrupción'),
#  ('Parvati Lopez', 2, 'La travesura de el tesoro'),
#  ('Mehmet Cruz', 4, 'El eclipse de la montaña'),
#  ('Fadhila Duarte', 4, 'El hechizo de la luz'),
#  ('Mina Lopez', 4, 'El hechizo de la luz'),
#  ('Fadhila Fernandes', 3, 'El misterio de la guerra'),
#  ('Wang Santos', 6, 'La canción de el cielo'),
#  ('Fadhila Duarte', 4, 'El eclipse de la montaña'),
#  ('Jasmin Lopes', 6, 'La estrella fugaz de el encuentro'),
#  ('Mikhail Gomes', 5, 'El caballero de el dragón'),
#  ('Salim Fernandes', 2, 'La fortuna de el río'),
#  ('Wilhelmina Yan', 3, 'El despertar de la compañía'),
#  ('Zafar Quintana', 6, 'La batalla de el río'),
#  ('Mehmet Cruz', 4, 'La rebelión de la noche'),
#  ('Abdullah Queiroz', 2, 'El vuelo mágico de la bienvenida'),
#  ('Katarina Xia', 5, 'La batalla de la mariposa'),
#  ('Rashid Santos', 3, 'El cuento de hadas de la oscuridad'),
#  ('Zafar Quintana', 6, 'La danza macabra de la soledad'),
#  ('Fadhila Fernandes', 3, 'La estirpe de el misterio'),
#  ('Tatiana Gomes', 4, 'La profecía de el muro'),
#  ('Irina Nunes', 3, 'La leyenda de el camino'),
#  ('Wang Montenegro', 7, 'El castillo de la despedida'),
#  ('Zoya Santana', 2, 'La trampa de el secreto'),
#  ('Han Henriquez', 8, 'El descubrimiento de la cueva'),
#  ('Alessandro Carvalho', 3, 'El arco iris de el sol'),
#  ('Rania Inácio', 4, 'El viaje de la luz'),
#  ('Mehmet Cruz', 4, 'La danza de la pesadilla'),
#  ('Yuri Teles', 4, 'La profecía de el bosque'),
#  ('Patricia Vargas', 3, 'El último viaje de el sapo'),
#  ('Jasmin Dutta', 6, 'La danza macabra de la soledad'),
#  ('Han Henriquez', 8, 'La travesura de el tesoro'),
#  ('Javier Ramos', 2, 'La leyenda perdida de el descubrimiento'),
#  ('Xin Henriquez', 2, 'El último viaje de la nube'),
#  ('Umberto Vargas', 5, 'El tesoro escondido de la redención'),
#  ('Ximena Vargas', 2, 'El castillo de la despedida'),
#  ('Fadhila Nogueira', 2, 'La fortuna de el viaje'),
#  ('Qiu Goncalves', 4, 'La estrella fugaz de el encuentro'),
#  ('Ursula Janssen', 2, 'El guardián de el atardecer'),
#  ('Giovanni Rocha', 3, 'La danza macabra de la soledad'),
#  ('Xin Henriquez', 2, 'El secreto de el amor'),
#  ('Leonardo Yilmaz', 2, 'La venganza de el lamento'),
#  ('Lakshmi Barros', 3, 'El bosque encantado de el enigma'),
#  ('Hiroko Xavier', 7, 'El eclipse de la montaña'),
#  ('Jasmin Lopes', 6, 'El arco iris de la espada'),
#  ('Sakura Yilmaz', 3, 'El misterio de el laberinto'),
#  ('Alessandro Joaquim', 2, 'La llave de la neblina'),
#  ('Xavier Figueiredo', 5, 'La estirpe de el laberinto'),
#  ('Alessandro Martinez', 5, 'La búsqueda de la ciudad'),
#  ('Alessandro Yilmaz', 4, 'La travesía sin retorno de el océano'),
#  ('Hiroko Ramos', 4, 'El secreto de la bestia'),
#  ('Han Henriquez', 8, 'Las aventuras de la corrupción'),
#  ('Valeria Teixeira', 2, 'La travesía del océano de la cárcel'),
#  ('Chen Rodriguez', 3, 'El renacimiento de la oscuridad'),
#  ('Nina Nogueira', 3, 'El espejismo de la estrella fugaz'),
#  ('Valentina Joaquim', 6, 'La travesía del océano de la estrella fugaz'),
#  ('Katarina Henriquez', 3, 'El viaje de la luna'),
#  ('Zara Carvalho', 2, 'La danza de la soledad'),
#  ('Xin Yamamoto', 2, 'El canto de sirena de la corona'),
#  ('Mina Lopez', 4, 'La conquista de la caverna'),
#  ('Fabiana Hernandez', 4, 'La fuente de la trampa'),
#  ('Valeria Almeida', 2, 'La maldición de la academia'),
#  ('Xavier Gomes', 3, 'La historia de la promesa'),
#  ('Xavier Ramos', 2, 'El espejismo de la estrella fugaz'),
#  ('Qiu Goncalves', 4, 'Las aventuras de el río'),
#  ('Xavier Figueiredo', 5, 'La llegada de el árbol'),
#  ('Oscar Zambrano', 4, 'La fuente de la trampa'),
#  ('Leonardo Nogueira', 3, 'La estrella fugaz de el unicornio'),
#  ('Wang Abadi', 3, 'Las aventuras de el destino'),
#  ('Samir Vieira', 2, 'El caballero de la promesa'),
#  ('Yusef Teles', 6, 'La canción de el cielo'),
#  ('Qiu Goncalves', 4, 'El resurgimiento de la caza'),
#  ('Valentina Joaquim', 6, 'La canción de el sol'),
#  ('Zafar Olivares', 5, 'El canto de sirena de la corona'),
#  ('Tatjana Quintana', 5, 'El príncipe de la flor'),
#  ('Patricia Vargas', 3, 'La travesía sin retorno de el océano'),
#  ('Aarav Gao', 3, 'El hechizo de la travesía'),
#  ('Parvati Lopez', 2, 'La maldición de la gruta'),
#  ('Mikhail Pacheco', 3, 'La metamorfosis de la travesía'),
#  ('Sakura Yilmaz', 3, 'El vuelo mágico de la estrella'),
#  ('Zara Nogueira', 2, 'La canción de el sol'),
#  ('Zoya Mendes', 2, 'La batalla de el ángel'),
#  ('Lakshmi Rodriguez', 2, 'El renacimiento de la oscuridad'),
#  ('Yasmin Hidalgo', 5, 'El eclipse de la montaña'),
#  ('Xin Yamamoto', 2, 'La rebelión de la noche'),
#  ('Valeria Xia', 3, 'El misterio de la fortuna'),
#  ('Jasmin Lopes', 6, 'La estirpe de la alianza'),
#  ('Zafar Quintana', 6, 'La travesía del océano de la cárcel'),
#  ('Chidike Alvarez', 2, 'La estirpe de el misterio'),
#  ('Hiroko Ramos', 4, 'El grito de el amanecer'),
#  ('Wang Montenegro', 7, 'El descubrimiento de la guerra'),
#  ('Mikhail Pacheco', 3, 'El ritual de el viaje'),
#  ('Xavier Figueiredo', 5, 'La búsqueda de el renacer'),
#  ('Giovanni Carvalho', 4, 'El misterio de la fortuna'),
#  ('Javier Petrov', 2, 'La odisea de el horizonte'),
#  ('Fatemeh Carvalho', 4, 'El enigma de la ley'),
#  ('Yusef Yilmaz', 4, 'La danza macabra de el laberinto'),
#  ('Alessandro Carvalho', 4, 'El príncipe de la flor'),
#  ('Giovanni Carvalho', 4, 'La travesía del océano de el rincón'),
#  ('Mikhail Gomes', 5, 'El despertar de la estrella'),
#  ('Fabiana Lopes', 2, 'La danza macabra de el laberinto'),
#  ('Yuri Teles', 4, 'La canción de el sol'),
#  ('Beatriz Nguyen', 2, 'El tesoro escondido de la luz'),
#  ('Quentin Janssen', 4, 'La búsqueda de la travesía'),
#  ('Rosa Urbina', 3, 'El renacimiento de la amistad'),
#  ('Ximena Jimenez', 5, 'La fuga de la promesa'),
#  ('Lakshmi Barros', 3, 'La rebelión de la noche'),
#  ('Orhan Gao', 5, 'El lamento de la huida'),
#  ('Han Henriquez', 8, 'El refugio de el peligro'),
#  ('Alessandro Carvalho', 3, 'El grito de la profecía'),
#  ('Oscar Zambrano', 4, 'La leyenda perdida de el león'),
#  ('Aarav Pacheco', 2, 'La travesía de el guardián'),
#  ('Zara Nogueira', 2, 'La danza de la soledad'),
#  ('Lakshmi Pacheco', 4, 'El renacimiento de el hechizo'),
#  ('Irina Nunes', 3, 'La danza de el amor'),
#  ('Yuri Teles', 4, 'El caballero de el dragón'),
#  ('Alessandro Martinez', 5, 'El arco iris de el sol'),
#  ('Orhan Gao', 5, 'El refugio de la libertad'),
#  ('Rania Pacheco', 2, 'La fuente de la trampa'),
#  ('Wang Santos', 6, 'El destino de la corrupción'),
#  ('Valeria Kumar', 5, 'La danza macabra de el camino'),
#  ('Fadhila Duarte', 4, 'El misterio de la guerra'),
#  ('Pilar Estevez', 4, 'La leyenda de el desafío'),
#  ('Zafar Olivares', 5, 'El secreto oscuro de el lobo'),
#  ('Leonardo Yilmaz', 2, 'La búsqueda del tesoro de el guerrero'),
#  ('Tatiana Yilmaz', 3, 'El vuelo mágico de la estrella'),
#  ('Rosa Rodriguez', 5, 'El guardián de la flor'),
#  ('Zara Carvalho', 2, 'El grito de la caída'),
#  ('Mikhail Gomes', 5, 'La fortuna de el río'),
#  ('Irina Nunes', 3, 'El canto de sirena de la mariposa'),
#  ('Rosa Urbina', 3, 'La batalla de la espada'),
#  ('Zoya Mendes', 2, 'La maldición del vampiro de la trampa'),
#  ('Abdullah Queiroz', 2, 'La fuga de la reina'),
#  ('Nina Nogueira', 3, 'El canto de sirena de la corona'),
#  ('Akira Kawaguchi', 2, 'La danza de la pesadilla'),
#  ('Parvati Pacheco', 3, 'La senda de el árbol'),
#  ('Valeria Almeida', 2, 'El bosque encantado de la guerra'),
#  ('Mikhail Pacheco', 3, 'La invasión de la salvación'),
#  ('Ximena Ramos', 2, 'El caballero de el dragón'),
#  ('Zara Janssen', 2, 'La batalla de el puente'),
#  ('Jasmin Lopes', 6, 'La senda de el árbol'),
#  ('Xin Zambrano', 2, 'La trampa de la compañía'),
#  ('Mehmet Goncalves', 4, 'La escalada de la heroína'),
#  ('Theresa Yan', 7, 'La maldición del vampiro de la trampa'),
#  ('Yasmin Hidalgo', 5, 'El despertar de la compañía'),
#  ('Giovanni Rocha', 3, 'La leyenda de el desafío'),
#  ('Mehmet Goncalves', 4, 'El camino hacia la ola'),
#  ('Nina Nogueira', 3, 'La fuga de el guerrero'),
#  ('Tatiana Montenegro', 5, 'La travesura de el misterio'),
#  ('Leonardo Nogueira', 3, 'El renacimiento de la luz'),
#  ('Valentina Joaquim', 6, 'Las aventuras de la prisión'),
#  ('Leticia Ramos', 2, 'La profecía de el bosque'),
#  ('Chen Jimenez', 4, 'La profecía de el laberinto'),
#  ('Aarav Diniz', 2, 'La leyenda perdida de el peligro'),
#  ('Katarina Henriquez', 3, 'La travesía del océano de la cárcel'),
#  ('Quentin Janssen', 4, 'El hechizo de la luz'),
#  ('Genghis Cruz', 4, 'La búsqueda de la travesía'),
#  ('Lakshmi Rodriguez', 2, 'La leyenda de el muro'),
#  ('Salim Ivanov', 5, 'La batalla de el ángel'),
#  ('Giovanni Xia', 2, 'La danza macabra de la soledad'),
#  ('Salim Fernandes', 2, 'La rebelión de la noche'),
#  ('Tatiana Montenegro', 5, 'La misión de la tormenta'),
#  ('Hiroko Ramos', 4, 'La danza macabra de el laberinto'),
#  ('Tatiana Gomes', 4, 'La fuga de el desafío'),
#  ('Abdullah Nogueira', 5, 'El misterio de la princesa'),
#  ('Zara Janssen', 2, 'El secreto de el secreto'),
#  ('Elif Ivanov', 2, 'La llegada de el árbol'),
#  ('Mina Quintana', 3, 'El resurgimiento de la verdad'),
#  ('Orhan Gao', 5, 'El castillo de el caos'),
#  ('Fatemeh Carvalho', 4, 'La leyenda perdida de el descubrimiento'),
#  ('Yusef Yilmaz', 4, 'La travesía del océano de la estrella fugaz'),
#  ('Yasmin Hidalgo', 5, 'La llave de la neblina'),
#  ('Alessandro Martinez', 5, 'La batalla de la espada'),
#  ('Ximena Jimenez', 5, 'El pacto de la tierra'),
#  ('Akira Kawaguchi', 2, 'El secreto oscuro de el valle'),
#  ('Salim Ivanov', 5, 'El guardián de el cielo'),
#  ('Wang Montenegro', 7, 'La rebelión de la noche'),
#  ('Hanako Uchoa', 3, 'La resurrección de la bruja'),
#  ('Valentina Joaquim', 6, 'El castillo de el caos'),
#  ('Jasmin Dutta', 6, 'La fuga de la reina'),
#  ('Alessandro Carvalho', 4, 'El viaje de el misterio'),
#  ('Patricia Vargas', 3, 'El castillo de la despedida'),
#  ('Wang Ferreira', 3, 'La travesura de el misterio'),
#  ('Hiroko Xavier', 7, 'El guardián de la aldea'),
#  ('Lakshmi Oliveira', 4, 'La danza de la pesadilla'),
#  ('Wilhelmina Yan', 3, 'La estirpe de la venganza'),
#  ('Mikhail Gomes', 5, 'La estrella fugaz de el unicornio'),
#  ('Natalia Esteves', 3, 'La sombra de la criatura'),
#  ('Katarina Xia', 5, 'El descubrimiento de la cárcel'),
#  ('Han Henriquez', 8, 'El viaje de la luna'),
#  ('Valeria Kumar', 5, 'El guardián de el cielo'),
#  ('Umberto Vargas', 5, 'El secreto oscuro de el puente'),
#  ('Qiu Goncalves', 4, 'La trampa de el laberinto'),
#  ('Fadhila Yamamoto', 2, 'La estirpe de la batalla'),
#  ('Leticia Ramos', 2, 'La senda de el mito'),
#  ('Umberto Vargas', 5, 'La escalada de la heroína'),
#  ('Xin Santana', 3, 'La escalada de la sombra'),
#  ('Parvati Pacheco', 3, 'La danza macabra de la aventura'),
#  ('Tatiana Yilmaz', 3, 'El príncipe de la traición'),
#  ('Salim Ivanov', 5, 'La travesía del océano de el rincón'),
#  ('Valeria Kumar', 5, 'El renacimiento de el hechizo'),
#  ('Hanako Lopez', 3, 'El grito de la caída'),
#  ('Hiroko Xavier', 7, 'La rebelión de la pesadilla'),
#  ('Zafar Quintana', 6, 'El viaje de la guerra'),
#  ('Wang Santos', 6, 'La travesía sin retorno de la despedida'),
#  ('Aarav Diniz', 2, 'La fuga de la traición'),
#  ('Samir Vieira', 2, 'La escalada de la sombra'),
#  ('Yasmin Xavier', 2, 'Las aventuras de el destino'),
#  ('Salim Zhang', 2, 'El descubrimiento de la cueva'),
#  ('Giovanni Rocha', 3, 'El arco iris de el sol'),
#  ('Pilar Estevez', 4, 'El vuelo de la sirena'),
#  ('Orhan Gao', 5, 'La maldición de el mago'),
#  ('Hiroko Xavier', 7, 'La travesía de la trampa'),
#  ('Jasmin Dutta', 6, 'El secreto oscuro de el puente'),
#  ('Xavier Gomes', 3, 'La maldición de la promesa'),
#  ('Beatriz Carvalho', 4, 'La maldición del vampiro de la aldea'),
#  ('Beatriz Nguyen', 2, 'La metamorfosis de el pacto'),
#  ('Xin Santana', 3, 'El despertar de la estrella'),
#  ('Parvati Santana', 4, 'La fuga de la reina'),
#  ('Beatriz Carvalho', 4, 'La maldición del vampiro de la travesía'),
#  ('Rania Inácio', 4, 'El regreso de la pesadilla'),
#  ('Fadhila Duarte', 4, 'El arco iris de el sol'),
#  ('Genghis Cruz', 4, 'La misión de la sombra'),
#  ('Ximena Jimenez', 5, 'El descubrimiento de la neblina'),
#  ('Yusef Teles', 6, 'El grito de el pacto'),
#  ('Alessandro Oliveira', 2, 'La estirpe de el amor'),
#  ('Genghis Yilmaz', 2, 'La travesía de el hechizo'),
#  ('Xin Zambrano', 2, 'El lamento de la huida'),
#  ('Ximena Vargas', 2, 'La fortuna de el rincón'),
#  ('Darya Gao', 3, 'El tesoro escondido de la gruta'),
#  ('Chidike Yilmaz', 2, 'La canción de la despedida'),
#  ('Orhan Gao', 5, 'La estrella fugaz de la prisión'),
#  ('Umberto Vargas', 5, 'La fuente de la bienvenida'),
#  ('Zafar Quintana', 6, 'La llave de la guerra'),
#  ('Parvati Santana', 4, 'La estrella fugaz de el unicornio'),
#  ('Quentin Janssen', 4, 'La maldición del vampiro de la aventura'),
#  ('Jasmin Lopes', 6, 'La travesía de el hechizo'),
#  ('Rania Inácio', 4, 'El secreto oscuro de el puente'),
#  ('Fatemeh Bianchi', 2, 'La cripta de la amistad'),
#  ('Giovanni Xia', 2, 'El castillo de la despedida'),
#  ('Valentina Oliveira', 2, 'El guardián de la flor'),
#  ('Katarina Xia', 5, 'El regreso de la pesadilla'),
#  ('Tatiana Montenegro', 5, 'La fuga de la reina'),
#  ('Darya Gao', 3, 'La travesía del océano de la estrella fugaz'),
#  ('Hiroko Xavier', 7, 'La travesía del océano de la cárcel'),
#  ('Khaled Henriquez', 2, 'La tormenta de el monstruo'),
#  ('Umberto Alvarez', 2, 'La maldición del vampiro de la travesía'),
#  ('Leonardo Nogueira', 3, 'La canción de el sol'),
#  ('Valentina Joaquim', 6, 'El último viaje de el sapo'),
#  ('Mikhail Gomes', 5, 'La búsqueda del tesoro de la leyenda'),
#  ('Abdullah Nogueira', 5, 'La búsqueda del tesoro de la leyenda'),
#  ('Tatiana Gomes', 4, 'El renacimiento de el ángel'),
#  ('Javier Petrov', 2, 'El caballero de la puerta'),
#  ('Lakshmi Pacheco', 4, 'Las aventuras de la bienvenida'),
#  ('Yasmin Hidalgo', 5, 'El resurgimiento de la verdad'),
#  ('Lakshmi Oliveira', 4, 'El grito de la profecía'),
#  ('Zoya Santana', 2, 'La fuga de el guerrero'),
#  ('Alessandro Carvalho', 4, 'El guardián de el laberinto'),
#  ('Fatemeh Teixeira', 3, 'El lamento de la huida'),
#  ('Ursula Janssen', 2, 'La travesura de la trampa'),
#  ('Lakshmi Oliveira', 4, 'El cuento de hadas de la oscuridad'),
#  ('Genghis Cruz', 4, 'El descubrimiento de la guerra'),
#  ('Jin Carvalho', 2, 'El espejismo de el monstruo'),
#  ('Khaled Henriquez', 2, 'El tesoro escondido de el valle'),
#  ('Natalia Gao', 2, 'La senda de el árbol'),
#  ('Leonardo Kumar', 2, 'La búsqueda de la ciudad'),
#  ('Chen Rodriguez', 3, 'El canto de sirena de la espada mágica'),
#  ('Theresa Yan', 7, 'La danza de la pesadilla'),
#  ('Jasmin Lopes', 6, 'La trampa de el volcán'),
#  ('Alessandro Yilmaz', 4, 'La travesía sin retorno de el viajero'),
#  ('Chen Jimenez', 4, 'La danza macabra de el amor'),
#  ('Wang Abadi', 3, 'El cuento de hadas de el misterio'),
#  ('Alessandro Martinez', 5, 'La rebelión de la profecía'),
#  ('Mehmet Goncalves', 4, 'La batalla de la sombra'),
#  ('Salim Ivanov', 5, 'El descubrimiento de la guerra'),
#  ('Quentin Janssen', 4, 'La batalla de el río'),
#  ('Tatiana Montenegro', 5, 'La leyenda de la bruma'),
#  ('Fatemeh Bianchi', 2, 'La sombra de el guerrero'),
#  ('Rania Pacheco', 2, 'La fuga de el adiós'),
#  ('Parvati Santana', 4, 'El castillo de el caos'),
#  ('Alessandro Oliveira', 2, 'La senda de el mito'),
#  ('Fadhila Yamamoto', 2, 'La rebelión de la pesadilla'),
#  ('Rania Inácio', 4, 'La leyenda de el encuentro'),
#  ('Umberto Xia', 3, 'La tormenta de la aldea'),
#  ('Mehmet Yan', 2, 'El castillo de la luna'),
#  ('Tatjana Quintana', 5, 'El secreto oscuro de el lobo'),
#  ('Pilar Estevez', 4, 'El tesoro de la pesadilla'),
#  ('Rashid Santos', 3, 'El arco iris de la espada mágica'),
#  ('Umberto Xia', 3, 'La maldición del vampiro de la escuela'),
#  ('Valeria Kumar', 5, 'La fuga de la reina'),
#  ('Rashid Santos', 3, 'La danza macabra de el camino'),
#  ('Rosa Rodriguez', 5, 'El descubrimiento de la neblina'),
#  ('Theresa Yan', 7, 'La escalada de la heroína'),
#  ('Zafar Quintana', 6, 'El canto de sirena de el mar'),
#  ('Giovanni Kawaguchi', 2, 'La travesía sin retorno de la despedida'),
#  ('Valeria Teixeira', 2, 'El vuelo mágico de la bienvenida'),
#  ('Tatiana Montenegro', 5, 'El canto de sirena de la mariposa'),
#  ('Hiroko Ramos', 4, 'El secreto de la estrella'),
#  ('Natalia Gao', 2, 'El guardián de el laberinto'),
#  ('Tatiana Montenegro', 5, 'El ritual de la selva'),
#  ('Natalia Esteves', 3, 'La estrella fugaz de la senda'),
#  ('Fabiana Hernandez', 4, 'El vuelo mágico de la estrella'),
#  ('Javier Ramos', 2, 'La travesura de el misterio'),
#  ('Rosa Rodriguez', 5, 'La llegada de el árbol'),
#  ('Tatjana Quintana', 5, 'La odisea de el horizonte'),
#  ('Salim Ivanov', 5, 'La resurrección de la noche'),
#  ('Lakshmi Oliveira', 4, 'La travesía del océano de la alianza'),
#  ('Zafar Olivares', 5, 'La fuga de el adiós'),
#  ('Valeria Kumar', 5, 'El descubrimiento de la muralla'),
#  ('Theresa Yan', 7, 'El príncipe de la flor'),
#  ('Tatiana Montenegro', 5, 'El último viaje de el sapo'),
#  ('Sakura Yilmaz', 3, 'La travesía del océano de la cárcel'),
#  ('Alessandro Yilmaz', 4, 'El misterio de la princesa'),
#  ('Wang Montenegro', 7, 'La canción de la despedida'),
#  ('Xavier Ramos', 2, 'El viaje de el misterio'),
#  ('Aarav Gao', 3, 'El descubrimiento de la cueva'),
#  ('Lakshmi Pacheco', 4, 'El caballero de la puerta'),
#  ('Valentina Joaquim', 6, 'El secreto oscuro de el valle'),
#  ('Aarav Watanabe', 2, 'La travesía de el guardián'),
#  ('Wilhelmina Carvalho', 2, 'La canción de la despedida'),
#  ('Parvati Pacheco', 3, 'El espejismo de el monstruo'),
#  ('Wang Ferreira', 3, 'La llave de la neblina'),
#  ('Lakshmi Pacheco', 4, 'La maldición de el mago'),
#  ('Hiroko Xavier', 7, 'La maldición del vampiro de la aldea'),
#  ('Genghis Nguyen', 2, 'El tesoro de la pesadilla'),
#  ('Xavier Figueiredo', 5, 'El enigma de la corona'),
#  ('Ximena Yan', 2, 'La travesía sin retorno de la despedida'),
#  ('Alessandro Carvalho', 3, 'La batalla de la mariposa'),
#  ('Beatriz Carvalho', 4, 'El refugio de la libertad'),
#  ('Tatiana Montenegro', 5, 'El guardián de el atardecer'),
#  ('Fatemeh Teixeira', 3, 'El laberinto de la paz'),
#  ('Wang Santos', 6, 'La danza de el dragón'),
#  ('Wang Abadi', 3, 'El pacto de el guardián'),
#  ('Umberto Vargas', 5, 'El castillo de la luna'),
#  ('Katarina Henriquez', 3, 'El pacto de el río'),
#  ('Tatjana Quintana', 5, 'El lamento de la huida'),
#  ('Beatriz Carvalho', 4, 'La batalla de la mariposa'),
#  ('Aarav Pacheco', 2, 'El laberinto de la bailarina'),
#  ('Hanako Lopez', 3, 'La fuga de la promesa'),
#  ('Ximena Jimenez', 5, 'La fuente de la sirena'),
#  ('Rosa Rodriguez', 5, 'El último viaje de la nube'),
#  ('Valeria Kumar', 5, 'La batalla de la bienvenida'),
#  ('Xin Santana', 3, 'La leyenda perdida de la libertad'),
#  ('Parvati Santana', 4, 'El pacto de la tierra'),
#  ('Valeria Xia', 3, 'La historia de la promesa'),
#  ('Fabiana Lopes', 2, 'El guardián de el cielo'),
#  ('Mina Lopez', 4, 'La travesía sin retorno de la magia'),
#  ('Leonardo Kumar', 2, 'El refugio de la libertad'),
#  ('Giovanni Carvalho', 4, 'La travesía sin retorno de la magia'),
#  ('Ximena Yan', 2, 'El misterio de la fortuna'),
#  ('Oscar Zambrano', 4, 'El castillo de el caos'),
#  ('Chen Jimenez', 4, 'El grito de la caída'),
#  ('Alessandro Yilmaz', 4, 'El refugio de la puerta'),
#  ('Hanako Lopez', 3, 'La maldición del vampiro de la aventura'),
#  ('Theresa Yan', 7, 'La danza de la soledad'),
#  ('Xavier Figueiredo', 5, 'La fuga de la traición'),
#  ('Wilhelmina Carvalho', 2, 'El castillo de la luna'),
#  ('Giovanni Carvalho', 4, 'El camino hacia la ciudad'),
#  ('Aarav Gao', 3, 'La fuente de la bienvenida'),
#  ('Umberto Xia', 3, 'La fuga de la reina'),
#  ('Alessandro Joaquim', 2, 'La travesura de el tesoro'),
#  ('Parvati Pereira', 3, 'El destino de la corrupción'),
#  ('Theresa Yan', 7, 'La fuga de la traición'),
#  ('Theresa Yan', 7, 'La rebelión de la pesadilla'),
#  ('Fabiana Hernandez', 4, 'La travesía del océano de la estrella fugaz'),
#  ('Yuri Teles', 4, 'El resurgimiento de la verdad'),
#  ('Theresa Diniz', 2, 'La misión de la sombra'),
#  ('Genghis Yilmaz', 2, 'La travesura de el misterio'),
#  ('Darya Gao', 3, 'La historia de el amor'),
#  ('Natalia Esteves', 3, 'La maldición del vampiro de el ángel'),
#  ('Ilya Montenegro', 2, 'La leyenda perdida de el león'),
#  ('Wang Santos', 6, 'El ritual de la selva'),
#  ('Fadhila Nogueira', 2, 'El laberinto de la bailarina'),
#  ('Wilhelmina Yan', 3, 'El enigma de la sombra'),
#  ('Pilar Estevez', 4, 'La canción de el sol'),
#  ('Valentina Oliveira', 2, 'La travesura de el misterio'),
#  ('Fatemeh Carvalho', 4, 'La historia de el amor'),
#  ('Wang Montenegro', 7, 'El destino de el abismo'),
#  ('Alessandro Martinez', 5, 'La leyenda perdida de el amor'),
#  ('Parvati Pereira', 3, 'La misión de la sombra'),
#  ('Han Henriquez', 8, 'La leyenda perdida de el descubrimiento'),
#  ('Tatiana Montenegro', 5, 'La cripta de la luz'),
#  ('Tatiana Yilmaz', 3, 'El despertar de la compañía'),
#  ('Tatiana Montenegro', 5, 'La invasión de la salvación'),
#  ('Fatemeh Carvalho', 4, 'El pacto de la expedición'),
#  ('Yasmin Xavier', 2, 'El pacto de el pacto'),
#  ('Zafar Olivares', 5, 'La batalla de el puente'),
#  ('Hiroko Xavier', 7, 'El enigma de la ley'),
#  ('Hanako Uchoa', 3, 'La travesía del océano de la cárcel'),
#  ('Yusef Teles', 6, 'La cripta de la luz'),
#  ('Mina Quintana', 3, 'El pacto de el guardián'),
#  ('Wang Santos', 6, 'La fuga de la prisión'),
#  ('Elif Ivanov', 2, 'La maldición del vampiro de la aldea'),
#  ('Tatjana Quintana', 5, 'El lamento de la clave'),
#  ('Yusef Teles', 6, 'El resurgimiento de la caverna'),
#  ('Han Henriquez', 8, 'El enigma de la sombra'),
#  ('Wang Montenegro', 7, 'La fuga de la reina'),
#  ('Rosa Rodriguez', 5, 'El eclipse de la montaña'),
#  ('Mehmet Goncalves', 4, 'La maldición de el secreto'),
#  ('Salim Zhang', 2, 'El guardián de el laberinto'),
#  ('Mehmet Cruz', 4, 'Las aventuras de la prisión'),
#  ('Xavier Gomes', 3, 'La estirpe de el árbol'),
#  ('Mina Quintana', 3, 'La estrella fugaz de el peligro'),
#  ('Mina Lopez', 4, 'La estrella fugaz de la expedición'),
#  ('Yusef Teles', 6, 'La maldición de la cárcel'),
#  ('Fatemeh Teixeira', 3, 'La maldición del vampiro de la aldea'),
#  ('Rosa Urbina', 3, 'La leyenda perdida de la estrella fugaz'),
#  ('Genghis Nguyen', 2, 'La batalla de la sombra'),
#  ('Umberto Alvarez', 2, 'La travesura de la trampa'),
#  ('Parvati Pereira', 3, 'El príncipe de la flor'),
#  ('Theresa Diniz', 2, 'La fuga de la prisión'),
#  ('Abdullah Nogueira', 5, 'El viaje de la alianza'),
#  ('Chidike Yilmaz', 2, 'La fuga de la ciudad'),
#  ('Yusef Yilmaz', 4, 'La conquista de la caverna'),
#  ('Genghis Cruz', 4, 'La fuga de la traición'),
#  ('Yusef Teles', 6, 'El guardián de la aldea'),
#  ('Jin Carvalho', 2, 'El viaje de la luna'),
#  ('Fabiana Hernandez', 4, 'El despertar de la estrella'),
#  ('Lakshmi Barros', 3, 'El cuento de hadas de la pasión'),
#  ('Han Henriquez', 8, 'La venganza de el lamento'),
#  ('Hanako Uchoa', 3, 'El príncipe de la flor'),
#  ('Chen Jimenez', 4, 'El descubrimiento de la compañía'),
#  ('Chidike Alvarez', 2, 'El último viaje de la nube'),
#  ('Ilya Montenegro', 2, 'La travesía del océano de la alianza'),
#  ('Alessandro Carvalho', 4, 'El renacimiento de el ángel'),
#  ('Jasmin Dutta', 6, 'El viaje de la caída'),
#  ('Valeria Xia', 3, 'El renacimiento de la luz'),
#  ('Yusef Yilmaz', 4, 'El tesoro de la pesadilla'),
#  ('Ximena Jimenez', 5, 'El espejismo de la estrella fugaz'),
#  ('Tatiana Gomes', 4, 'El pacto de el guardián'),
#  ('Wang Montenegro', 7, 'La travesía del océano de la cárcel'),
#  ('Fadhila Fernandes', 3, 'El viaje de el misterio'),
#  ('Giovanni Kawaguchi', 2, 'La llegada de el árbol'),
#  ('Zafar Olivares', 5, 'La búsqueda del tesoro de la leyenda'),
#  ('Aarav Watanabe', 2, 'La fuga de el desafío'),
#  ('Abdullah Nogueira', 5, 'El secreto oscuro de el puente'),
#  ('Tatjana Quintana', 5, 'La metamorfosis de la travesía')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
